# %% [markdown]
# # MANUela Anomaly ML Model
#
# Goal: Build a machine lerning model that detects anomalies in sensor vibration data
#
# ![anomalies](https://raw.githubusercontent.com/sa-mw-dach/manuela/master/docs/images/manuela-anomalies.png)
#
# Steps:
# - Wrangling sensor data
# - Save the training data
# - Prepare the data for modeling, training and testing
# - Train and validate models
# - Select and save the best model
# - Prototype class for Seldon model serving
#
# *Note: This is an extension of the initial notebook, where Deep Learning Model (LSTM Autoencoder) has been introduced.*

# %% [markdown]
# ### Table of Contents
#
# * [Chapter 1: Explore sensor data](#chapter1)
#     * [Section 1.1: Preview the raw data](#section_1_1)
#     * [Section 1.2: Visualize raw data over time](#section_1_2)
#     * [Section 1.3: Visualize labeled data over time](#section_1_3)
# * [Chapter 2: Data Wrangling](#chapter2)
#     * [Section 1.1: Explore the new data](#section_2_1)
#     * [Section 1.2: Save Training data to CSV](#section_2_2)
# * [Chapter 3: Data Preparation](#chapter3)
#     * [Section 1.1: Training and Testing Data Split](#section_3_1)
#     * [Section 1.2: Identify feature and target columns](#section_3_2)

# %% [markdown]
# ## Import libraries and define methods

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from time import time

from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report

# Statistical ML Models
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

# ML Framework and High Level API
import tensorflow as tf
from tensorflow import keras

from IPython.display import Markdown, display

def printmd(string):
    display(Markdown(string))

# %% [markdown]
# ## Explore sensor data  <a class="anchor" id="chapter1"></a>

# %%
# Retrieve data
df_initial = pd.read_csv('raw-data.csv')

# Set time as index
df_initial['time'] = pd.to_datetime(df_initial['ts'],unit='ms')
df_initial.set_index('time', inplace=True)
df_initial.drop(columns=['ts'], inplace=True)

# %% [markdown]
# ### Preview the raw data   <a class="anchor" id="section_1_1"></a>

# %%
df_initial.head(20)
# Out:
#                              id      value  label
# time
# 2020-04-23 11:13:54.617  pump-1  18.340181      0
# 2020-04-23 11:13:57.999  pump-2  12.703972      0
# 2020-04-23 11:13:59.618  pump-1  17.647661      0
# 2020-04-23 11:14:02.999  pump-2  13.805114      0
# 2020-04-23 11:14:04.617  pump-1  16.874933      0
# 2020-04-23 11:14:07.999  pump-2  15.415206      0
# 2020-04-23 11:14:09.617  pump-1  16.180807      0
# 2020-04-23 11:14:12.999  pump-2  15.922729      0
# 2020-04-23 11:14:14.618  pump-1  15.407113      0
# 2020-04-23 11:14:17.999  pump-2  17.051560      0
# 2020-04-23 11:14:19.617  pump-1  15.324012      0
# 2020-04-23 11:14:22.999  pump-2  17.795010      0
# 2020-04-23 11:14:24.617  pump-1  13.470387      0
# 2020-04-23 11:14:27.999  pump-2  19.433830      0
# 2020-04-23 11:14:29.617  pump-1  11.702384      0
# 2020-04-23 11:14:32.999  pump-2  19.150144      0
# 2020-04-23 11:14:34.617  pump-1  11.176102      0
# 2020-04-23 11:14:37.999  pump-2  46.499027      1
# 2020-04-23 11:14:39.617  pump-1  10.678349      0
# 2020-04-23 11:14:42.999  pump-2  18.245524      0

# %%
df_initial.describe()
# Out:
#              value        label
# count  3022.000000  3022.000000
# mean     14.433740     0.027796
# std       4.539839     0.164416
# min       8.089854     0.000000
# 25%      11.725275     0.000000
# 50%      13.975456     0.000000
# 75%      16.180843     0.000000
# max      48.423213     1.000000

# %%
sns.distplot(df_initial['value'].dropna())
# Out:
# /home/fmurdaca/.local/share/virtualenvs/manuela-dev-SY9YZsQk/lib/python3.6/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='value', ylabel='Density'>

# %%
printmd(f"Data collected between **{min(df_initial.index)}** and **{max(df_initial.index)}**: **{df_initial.shape[0]}** samples from 2 pumps.")
total_time = max(df_initial.index) - min(df_initial.index)
printmd(f"Total time: **{total_time}**")

printmd(f"Time between samples: **{(total_time.seconds/df_initial.loc[(df_initial['id'] == 'pump-1')].shape[0])}** s")

for pump in df_initial['id'].unique():
    printmd(f"There are **{df_initial.loc[df_initial['id'] == pump].shape[0]}** samples for **{pump}**")
# Out:
# Data collected between **2020-04-23 11:13:54.617000** and **2020-04-23 13:19:47.999000**: **3022** samples from 2 pumps.
# Total time: **0 days 02:05:53.382000**
# Time between samples: **4.9986763732627395** s
# There are **1511** samples for **pump-1**
# There are **1511** samples for **pump-2**

# %% [markdown]
# ### Visualize raw data over time   <a class="anchor" id="section_1_2"></a>

# %% [markdown]
# All data

# %%
fig= plt.figure(figsize=(20,10))

for pump in df_initial['id'].unique():
    y = df_initial.loc[(df_initial['id'] == pump)]
    df_time = [pd.to_datetime(t) for t in y.index]
    plt.plot(df_time, y["value"].values, label=pump)

plt.legend()
plt.title("Pump 1/2 - All Data")
plt.xlabel("Time")
plt.xticks(rotation=90)
plt.ylabel("Acceleration [m/s2]")
plt.show()

# %% [markdown]
# Vibration pump 1: Data shows a few anomalies

# %%
df1 = df_initial.loc[df_initial['id'] == 'pump-1']
df1 = df1.drop(columns=['id','label'])
df1.plot(figsize=(20,5),  fontsize=12,subplots=True,  title = "Pump 1")
plt.show()

# %% [markdown]
# Vibration pump 2: Data shows a few anomalies

# %%
df2 = df_initial.loc[df_initial['id'] == 'pump-2']
df2 = df2.drop(columns=['id','label'])
df2.plot(figsize=(20,5),  fontsize=12,subplots=True,  title = "Pump 2")
plt.show()

# %% [markdown]
# ### Visualize labeled data over time  <a class="anchor" id="section_1_3"></a>

# %% [markdown]
# - Vibration pump 1.
# - Label = 1 -> Anomanly
# - The (manually) labeled data makes few more anomalies visibile.

# %%
df1 = df_initial.loc[df_initial['id'] == 'pump-1']
df1 = df1.drop(columns=['id'])
df1.plot(figsize=(20,10),  fontsize=12,subplots=True,  title = "Pump 1")
plt.show()

# %% [markdown]
# Vibration pump 2:
# - Label = 1 -> Anomanly
# - The (manually) labeled data makes few more anomalies visibile.

# %%
df2 = df_initial.loc[df_initial['id'] == 'pump-2']
df2 = df2.drop(columns=['id'])
df2.plot(figsize=(20,10),  fontsize=12,subplots=True, title = "Pump 2")
plt.show()

# %% [markdown]
# Zoom into pump 2 data:
# - Here we see interesting anomalies that the machine learning mode should detect.

# %%
df21 = df2.head(100)
df21.plot(figsize=(20,10), fontsize=12,subplots=True, title = "Pump 2 - 100 Values")
plt.show()

# %% [markdown]
# ## Data Wrangling <a class="anchor" id="chapter2"></a>

# %% [markdown]
# Goal: Convert time series data into small episodes that can be uses for supervised learning.

# %%
#
# Few helper functions
#

# Get list with column names: F1, F2, Fn, L
def get_columns(n):
    f = []
    for x in range(1,n+1):
        f.append("F"+str(x))
    f.append("L")
    return f

# Create empty data frame
def create_empty_df(n):
    d= ([0.]*n)
    d.append(0)
    dfx = pd.DataFrame([d], columns=get_columns(n))
    dfx.drop(dfx.index[0], inplace=True)
    return dfx

# Create data frame with one row
def create_df(vals: list, label: int = 0):
    if not isinstance(vals, list):
        raise TypeError
    #vals.append(label)    
    dfx = pd.DataFrame([vals+[label]], columns=get_columns(len(vals)))
    return dfx

# %% [markdown]
# Create a new dataframe: Rows represent the last x (length) value and the label.
#
# ```
# --+-----+-----
# tz value label
# --+-----+-----
# ..  ...    0
# 04  6.2    0
# 05  7.2    0
# 06  3.1    0
# 07 12.4    1
# ..  ...
# --+-----+-----
# ```
#
# Convert to episodes with lenght = 3
#
# ```
# ---+----+----+---
# F1   F2   F3   L
# ---+----+----+---
# ..
# 6.2  7.2  3.1  0
# 7.2  3.1 12.4  1
# ..
# ---+----+----+---
# ```

# %%
length = 5 # Episode lenght

df_epis = create_empty_df(length)

for id in df_initial.id.unique():
    print("Convert data for: ", id)
    
    df2 = df_initial.loc[df_initial['id'] == id]

    epi = []
    for index, row in df2.iterrows():
        # print('%6.2f, %d' % (row['value'], row['label']))
        epi.append(row['value'])
        if len(epi) == length :
            df_row = create_df(epi,row['label'] )
            df_epis = df_epis.append(df_row, ignore_index=True)
            del(epi[0])
# Out:
# Convert data for:  pump-1
# Convert data for:  pump-2

# %% [markdown]
# ### Explore the new data <a class="anchor" id="section_2_1"></a>

# %%
df_epis.head(20)
# Out:
#            F1         F2         F3         F4         F5  L
# 0   18.340181  17.647661  16.874933  16.180807  15.407113  0
# 1   17.647661  16.874933  16.180807  15.407113  15.324012  0
# 2   16.874933  16.180807  15.407113  15.324012  13.470387  0
# 3   16.180807  15.407113  15.324012  13.470387  11.702384  0
# 4   15.407113  15.324012  13.470387  11.702384  11.176102  0
# 5   15.324012  13.470387  11.702384  11.176102  10.678349  0
# 6   13.470387  11.702384  11.176102  10.678349   9.831242  0
# 7   11.702384  11.176102  10.678349   9.831242  11.555063  0
# 8   11.176102  10.678349   9.831242  11.555063  13.197594  0
# 9   10.678349   9.831242  11.555063  13.197594  14.337077  0
# 10   9.831242  11.555063  13.197594  14.337077  15.020920  0
# 11  11.555063  13.197594  14.337077  15.020920  15.802650  0
# 12  13.197594  14.337077  15.020920  15.802650  17.343995  0
# 13  14.337077  15.020920  15.802650  17.343995  16.413220  0
# 14  15.020920  15.802650  17.343995  16.413220  15.711286  0
# 15  15.802650  17.343995  16.413220  15.711286  14.035776  0
# 16  17.343995  16.413220  15.711286  14.035776  12.314211  0
# 17  16.413220  15.711286  14.035776  12.314211  11.173016  0
# 18  15.711286  14.035776  12.314211  11.173016  10.768019  0
# 19  14.035776  12.314211  11.173016  10.768019   9.691997  0

# %%
df_epis.describe()
# Out:
#                 F1           F2           F3           F4           F5  \
# count  3014.000000  3014.000000  3014.000000  3014.000000  3014.000000
# mean     14.419974    14.421438    14.430688    14.430566    14.429951
# std       4.514179     4.514390     4.544588     4.544510     4.544357
# min       8.089854     8.089854     8.089854     8.089854     8.089854
# 25%      11.724137    11.724137    11.724137    11.724137    11.724137
# 50%      13.961320    13.966907    13.971367    13.971367    13.971367
# 75%      16.179648    16.180626    16.180626    16.180626    16.179648
# max      48.423213    48.423213    48.423213    48.423213    48.423213
#
#                  L
# count  3014.000000
# mean      0.027870
# std       0.164627
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
# Calculate number of episodes
n_episodes = df_epis.shape[0]

# Calculate number of features
n_features = df_epis.shape[1] - 1

# Calculate passing students
n_anomaly = df_epis[df_epis['L']==1].shape[0]

# TODO: Calculate failing students
n_normal = df_epis[df_epis['L']==0].shape[0]

# TODO: Calculate graduation rate
anomaly_rate = n_anomaly / float(n_episodes) *100

# Print the results
print ("Total number of episodes: {}".format(n_episodes))
print ("Number of features: {}".format(n_features))
print ("Number of episodes with anomaly: {}".format(n_anomaly))
print ("Number of episodes witManipulatehout anomaly: {}".format(n_normal))
print ("Anomaly rate in dataset: {:.2f}%".format(anomaly_rate))
# Out:
# Total number of episodes: 3014
# Number of features: 5
# Number of episodes with anomaly: 84
# Number of episodes witManipulatehout anomaly: 2930
# Anomaly rate in dataset: 2.79%

# %% [markdown]
# Let's vary the anomalies to make the model more robust

# %%
factor = 5 # Number of copies
dfr = df_epis.copy()

increase_factor = 4.5

for i in range(1,factor):

    f = increase_factor + ((i - 1 ) * 0.5 / (factor-1)) # vary the anomaly by a factor 
    #print(i,f)
    
    dfi = df_epis.copy()
    dfi[f'F{length}'] = np.where(dfi['L']==1, dfi[f'F{length}']*f, dfi[f'F{length}']) # Lower the outliers
    dfr = dfr.append(dfi)
    
df_epis = dfr.copy()

# %%
# Calculate number of episodes
n_episodes = df_epis.shape[0]

# Calculate number of features
n_features = df_epis.shape[1] - 1

# Calculate passing students
n_anomaly = df_epis[df_epis['L']==1].shape[0]

# TODO: Calculate failing students
n_normal = df_epis[df_epis['L']==0].shape[0]

# TODO: Calculate graduation rate
anomaly_rate = n_anomaly / float(n_episodes) *100

# Print the results
print ("Total number of episodes: {}".format(n_episodes))
print ("Number of features: {}".format(n_features))
print ("Number of episodes with anomaly: {}".format(n_anomaly))
print ("Number of episodes without anomaly: {}".format(n_normal))
print ("Anomaly rate in dataset: {:.2f}%".format(anomaly_rate))
# Out:
# Total number of episodes: 15070
# Number of features: 5
# Number of episodes with anomaly: 420
# Number of episodes without anomaly: 14650
# Anomaly rate in dataset: 2.79%

# %% [markdown]
# ### Save Training data to CSV <a class="anchor" id="section_2_2"></a>

# %%
df_epis.to_csv ('sensor-training-data.csv', index = False, header=True, float_format='%.2f')

# %% [markdown]
# # Prepare the data for modeling, training and testing <a class="anchor" id="chapter3"></a>

# %% [markdown]
# - Identify feature and target columns
# - Training and Testing Data Split

# %% [markdown]
# ## Identify feature and target columns <a class="anchor" id="section_3_1"></a>

# %%
# Extract feature columns
feature_cols = list(df_epis.columns[:-1])

# Extract target column 'label'
target_col = df_epis.columns[-1] 

# Show the list of columns
print ("Feature columns:\n{}".format(feature_cols))
print ("\nTarget column: {}".format(target_col))

# Separate the data into feature data and target data (X_all and y_all, respectively)
X_all = df_epis[feature_cols]
y_all = df_epis[target_col]

# Show the feature information by printing the first five rows
print ("\nFeature values:")
print (X_all.head())
# Out:
# Feature columns:
# ['F1', 'F2', 'F3', 'F4', 'F5']
#
# Target column: L
#
# Feature values:
#           F1         F2         F3         F4         F5
# 0  18.340181  17.647661  16.874933  16.180807  15.407113
# 1  17.647661  16.874933  16.180807  15.407113  15.324012
# 2  16.874933  16.180807  15.407113  15.324012  13.470387
# 3  16.180807  15.407113  15.324012  13.470387  11.702384
# 4  15.407113  15.324012  13.470387  11.702384  11.176102

# %% [markdown]
# ## Training and Testing Data Split <a class="anchor" id="section_3_2"></a>

# %% [markdown]
# Statistical Models

# %%
X_train, X_test, y_train, y_test = train_test_split( X_all, y_all, test_size=0.33, random_state=42)


# Show the results of the split
printmd("Training set has {} samples.".format(X_train.shape[0]))
printmd("Testing set has {} samples.".format(X_test.shape[0]))

printmd("Anomaly rate of the training set: {:.2f}%".format(100 * (y_train == 1).mean()))
printmd("Anomaly rate of the testing set: {:.2f}%".format(100 * (y_test == 1).mean()))
# Out:
# Training set has 10096 samples.
# Testing set has 4974 samples.
# Anomaly rate of the training set: 2.76%
# Anomaly rate of the testing set: 2.83%

# %% [markdown]
# ## Training and Evaluating Statistical ML Models
# - Setup helper functions

# %% [markdown]
# ### Setup
# Run the code cell below to initialize three helper functions which you can use for training and testing supervised learning models. The functions are as follows:
# - `train_classifier` - takes as input a classifier and training data and fits the classifier to the data.
# - `predict_labels` - takes as input a fit classifier, features, and a target labeling and makes predictions using the F<sub>1</sub> score.
# - `train_predict` - takes as input a classifier, and the training and testing data, and performs `train_clasifier` and `predict_labels`.
#  - This function will report the F<sub>1</sub> score for both the training and testing data separately.

# %%
def train_classifier(clf, X_train, y_train):
    ''' Fits a classifier to the training data. '''
    
    # Start the clock, train the classifier, then stop the clock
    start = time()
    clf.fit(X_train, y_train)
    end = time()
    
    # Print the results
    print ("Trained model in {:.4f} seconds".format(end - start))

    
def predict_labels(clf, features, target):
    ''' Makes predictions using a fit classifier based on F1 score. '''
    
    # Start the clock, make predictions, then stop the clock
    start = time()
    y_pred = clf.predict(features)
    end = time()
    
    # Print and return results
    print ("Made predictions in {:.4f} seconds.".format(end - start))
    return f1_score(target.values, y_pred)


def train_predict(clf, X_train, y_train, X_test, y_test):
    ''' Train and predict using a classifer based on F1 score. '''
    
    # Indicate the classifier and the training set size
    print ("Training a {} using a training set size of {}. . .".format(clf.__class__.__name__, len(X_train)))
    
    # Train the classifier
    train_classifier(clf, X_train, y_train)
    
    # Print the results of prediction for both training and testing
    print ("F1 score for training set: {:.4f}.".format(predict_labels(clf, X_train, y_train)))
    f1_score_test = predict_labels(clf, X_test, y_test)
    print ("F1 score for test set: {:.4f}.".format(f1_score_test))
    
    return {
        "Model": clf.__class__.__name__,
        "Model type": "Statistical model",
        "F1 score": f1_score_test
    }

# %% [markdown]
# ### Testing Model Performance
#
# Let's test 3 supervised learning models:
# - A) Decision Trees
# - B) Support Vector Machines (SVM)
# - C) Gaussian Naive Bayes (GaussianNB)

# %%
my_random_seed = 42

# Initialize the three models
clf_A = DecisionTreeClassifier(random_state=my_random_seed)
clf_B = SVC(random_state=my_random_seed)
clf_C = GaussianNB()

#Collect results from each model
summary_results = []

# loop thru models, then thru train sizes
for clf in [clf_A, clf_B, clf_C]:
    print ("\n{}: \n".format(clf.__class__.__name__))
    summary_results.append(train_predict(clf, X_train, y_train, X_test, y_test))
        
                    

for clf in [clf_A, clf_B, clf_C]:
    print ('\nReport for {}:\n'.format(clf.__class__.__name__))
    print (classification_report(y_test, clf.predict(X_test)))
    print ('-'*52)
# Out:
# DecisionTreeClassifier:
#
# Training a DecisionTreeClassifier using a training set size of 10096. . .
# Trained model in 0.0071 seconds
# Made predictions in 0.0014 seconds.
# F1 score for training set: 1.0000.
# Made predictions in 0.0014 seconds.
# F1 score for test set: 1.0000.
#
# SVC:
#
# Training a SVC using a training set size of 10096. . .
# Trained model in 0.0186 seconds
# Made predictions in 0.0075 seconds.
# F1 score for training set: 1.0000.
# Made predictions in 0.0044 seconds.
# F1 score for test set: 1.0000.
#
# GaussianNB:
#
# Training a GaussianNB using a training set size of 10096. . .
# Trained model in 0.0028 seconds
# Made predictions in 0.0018 seconds.
# F1 score for training set: 0.9928.
# Made predictions in 0.0015 seconds.
# F1 score for test set: 0.9929.
#
# Report for DecisionTreeClassifier:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4833
#            1       1.00      1.00      1.00       141
#
#     accuracy                           1.00      4974
#    macro avg       1.00      1.00      1.00      4974
# weighted avg       1.00      1.00      1.00      4974
#
# ----------------------------------------------------
#
# Report for SVC:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4833
#            1       1.00      1.00      1.00       141
#
#     accuracy                           1.00      4974
#    macro avg       1.00      1.00      1.00      4974
# weighted avg       1.00      1.00      1.00      4974
#
# ----------------------------------------------------
#
# Report for GaussianNB:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4833
#            1       1.00      0.99      0.99       141
#
#     accuracy                           1.00      4974
#    macro avg       1.00      0.99      1.00      4974
# weighted avg       1.00      1.00      1.00      4974
#
# ----------------------------------------------------

# %% [markdown]
# The **precision** is the ratio ```tp / (tp + fp)``` where tp is the number of true positives and fp the number of false positives. The precision is intuitively the ability of the classifier not to label as positive a sample that is negative.
#
# The **recall** is the ratio ```tp / (tp + fn)``` where tp is the number of true positives and fn the number of false negatives. The recall is intuitively the ability of the classifier to find all the positive samples.
#
# The **F1 score** can be interpreted as a weighted average of the precision and recall, where an F1 score reaches its best value at 1 and worst score at 0. The relative contribution of precision and recall to the F1 score are equal. The formula for the F1 score is:
#
# ```F1 = 2 * (precision * recall) / (precision + recall)```
#
# The **support** is the number of occurrences of each class in ```y_true```.
#
# Source:
# [sklearn.metrics.precision_recall_fscore_support](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.precision_recall_fscore_support.html) [sklearn.metrics.f1_score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html)

# %% [markdown]
# ## Training and Evaluating Deep Learning Model: LSTM AutoEncoder

# %%
import os
# Create Keras callbacks
losses = []

def handleLoss(loss):
    global losses
    losses+=[loss]
    print(loss)
       
class CustomCallback(keras.callbacks.Callback):
    def on_train_begin(self, logs=None):
        keys = list(logs.keys())
        print("Starting training; got log keys: {}".format(keys))
        self.losses = []

    def on_train_end(self, logs=None):
        keys = list(logs.keys())
        print("Stop training; got log keys: {}".format(keys))

    def on_epoch_begin(self, epoch, logs=None):
        keys = list(logs.keys())
        print("Start epoch {} of training; got log keys: {}".format(epoch + 1, keys))

    def on_test_begin(self, logs=None):
        keys = list(logs.keys())
        print("Start testing; got log keys: {}".format(keys))

    def on_test_end(self, logs=None):
        keys = list(logs.keys())
        print("Stop testing; got log keys: {}".format(keys))

    def on_predict_begin(self, logs=None):
        keys = list(logs.keys())
        print("Start predicting; got log keys: {}".format(keys))

    def on_predict_end(self, logs=None):
        keys = list(logs.keys())
        print("Stop predicting; got log keys: {}".format(keys))
        

class SaveCallback(keras.callbacks.Callback):
    def __init__(self, model_name, model):
        super().__init__()
        self.best_loss = np.inf
        self.filedir = f"{model_name}_models/"
        self.model_ = model

    def on_epoch_end(self, epoch, logs=None):
        keys = list(logs.keys())
        if 'val_loss' in keys:
            if logs['val_loss'] < self.best_loss:
                savepath = self.filedir + 'epoch' + str(epoch + 1)
                print('\n' + 'Val_loss improved from ' + str(self.best_loss) + ' to ' + str(logs['val_loss']) + '. Saving model to ' + savepath + '/' + 'ckpt...')
                self.best_loss = logs['val_loss']
                if not os.path.exists(savepath):
                    os.makedirs(savepath)
                self.model_.save_weights(savepath + '/' + 'epoch' + str(epoch + 1) + 'ckpt')
            else:
                print('\n' + 'Val_loss did not improve from ' + str(self.best_loss))
                savepath = self.filedir + 'epoch' + str(epoch + 1)
                print('\n' + 'Val_loss improved from ' + str(self.best_loss) + ' to ' + str(logs['val_loss']) + '. Saving model to ' + savepath + '/' + 'ckpt...')
                self.best_loss = logs['val_loss']
                if not os.path.exists(savepath):
                    os.makedirs(savepath)
                self.model_.save_weights(savepath + '/' + 'epoch' + str(epoch + 1) + 'n' + 'ckpt')

# %%
# Create model

def get_model(X):
    """Get model."""
    new_model = keras.Sequential()

    new_model.add(keras.layers.LSTM(units=16,
                                input_shape=(X.shape[1],X.shape[2]),
                                activation='relu', return_sequences=True))
    new_model.add(keras.layers.LSTM(units=4, activation='relu'))
    new_model.add(keras.layers.RepeatVector(n=X.shape[1]))
    new_model.add(keras.layers.LSTM(units=4, activation='relu', return_sequences=True))
    new_model.add(keras.layers.LSTM(units=16, activation='relu', return_sequences=True))
    new_model.add(
      keras.layers.TimeDistributed(
        keras.layers.Dense(units=X.shape[2])
      )
    )
    
    new_model.summary()

    return new_model

# %%
# Create helper functions
def train(x_train_data, tot_epochs, selected_batch_size):
    """Train model."""
    new_model_ = get_model(X=x_train_data)

    new_model_.compile(loss='mae', optimizer='adam')
    history = new_model_.fit(
        x_train_data,
        x_train_data,
        epochs=tot_epochs,
        batch_size=selected_batch_size,
        validation_split=0.05,
        verbose=1,
        shuffle=False,
        callbacks=[CustomCallback(), SaveCallback(model_name="lstm_autoencoder", model=new_model_)]
    )
    
    return history, new_model_

def predict_results(newmodel, data):
    """Predict value."""
    predicted_value =  newmodel.predict(data)
    return predicted_value

# %% [markdown]
# Deep Learning Model: LSTM Autoencoder

# %% [markdown]
# ## Separate data in healthy and anomalies

# %%
healthy_data = df_initial.loc[(df_initial['label'] == 0)]
anomalies_data = df_initial.loc[(df_initial['label'] == 1)]

print(f"Total number of healthy samples is {healthy_data.shape[0]}")
percentage_anomalies = anomalies_data.shape[0]/df_initial.shape[0]*100
print(f"Total number of samples with anomalies is {anomalies_data.shape[0]} -> {percentage_anomalies:.2f}%")
# Out:
# Total number of healthy samples is 2938
# Total number of samples with anomalies is 84 -> 2.78%

# %%
df_epis_healthy = df_epis[df_epis['L'] == 0]
df_epis_anomalies = df_epis[df_epis['L'] == 1]

X_all_healthy = df_epis_healthy[feature_cols]
y_all_healthy = df_epis_healthy[target_col]

X_all_anomalies = df_epis_anomalies[feature_cols]
y_all_anomalies = df_epis_anomalies[target_col]

# %%
X_train_healthy, X_test_healthy, y_train_healthy, y_test_healthy = train_test_split(X_all_healthy, y_all_healthy, test_size=0.15, random_state=42)

# Show the results of the split
printmd("**Training healthy** set has **{}** samples.".format(X_train_healthy.shape[0]))
printmd("**Testing healthy** set has **{}** samples.".format(X_test_healthy.shape[0]))
# Out:
# **Training healthy** set has **12452** samples.
# **Testing healthy** set has **2198** samples.

# %% [markdown]
# ### Normalize the data
#
# When working with neural networks it is always good to scale data to a range between zero and one. Because we are planning to turn this notebook into a real-time anomaly detector for IoT sensor date we are defining a function instead of transforming the data so that we can make use of the transformer at later stage.

# %%
my_scaler = MinMaxScaler(feature_range=(0, 1))

# Fit scaling with train and the transform test and validation
my_scaler.fit(X_train_healthy)

X_train_healthy_scaled = pd.DataFrame(my_scaler.transform(X_train_healthy))
X_test_healthy_scaled = pd.DataFrame(my_scaler.transform(X_test_healthy))
X_all_anomalies_scaled = pd.DataFrame(my_scaler.transform(X_all_anomalies))

# %%
# Store set used to fit scaling to be reused in production
X_train_healthy.to_csv('sensor-training-data-for-scaling.csv', index = False, header=True, float_format='%.2f')

# %%
# plot both together to compare
fig, ax=plt.subplots(1,2)
sns.distplot(X_train_healthy, ax=ax[0])
ax[0].set_title("Original Data")
sns.distplot(X_train_healthy_scaled, ax=ax[1])
ax[1].set_title("Scaled data")
# Out:
# /home/fmurdaca/.local/share/virtualenvs/manuela-dev-SY9YZsQk/lib/python3.6/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/fmurdaca/.local/share/virtualenvs/manuela-dev-SY9YZsQk/lib/python3.6/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Scaled data')

# %% [markdown]
# ### Reshape inputs for LSTM (samples, timestamps, features)

# %%
x_train_healthy = X_train_healthy_scaled.values.reshape(X_train_healthy_scaled.shape[0], 1, X_train_healthy_scaled.shape[1])
print ("Training set healthy shape: {}".format(x_train_healthy.shape))

x_test_healthy = X_test_healthy_scaled.values.reshape(X_test_healthy_scaled.shape[0], 1, X_test_healthy_scaled.shape[1])
print ("Test set healthy shape: {}".format(x_test_healthy.shape))

x_all_anomalies = X_all_anomalies_scaled.values.reshape(X_all_anomalies_scaled.shape[0], 1, X_all_anomalies_scaled.shape[1])
print ("Set anomalies shape: {}".format(x_all_anomalies.shape))
# Out:
# Training set healthy shape: (12452, 1, 5)
# Test set healthy shape: (2198, 1, 5)
# Set anomalies shape: (420, 1, 5)

# %%
limit = 100

# %%
count = 0
for index, row in X_train_healthy_scaled.iterrows():
    row.plot()
    count += 1
    if count == limit:
        break

# %%
count = 0
for index, row in X_all_anomalies_scaled.iterrows():
    row.plot()
    count += 1
    if count == limit:
        break

# %% [markdown]
# Train Deep learning model

# %%
from pathlib import Path
import datetime
now = datetime.datetime.utcnow()
current_path = Path().cwd()

tot_epochs = 100
selected_batch_size = 1

history, lstm_autoencoder = train(
    x_train_data=x_train_healthy,
    tot_epochs=tot_epochs,
    selected_batch_size=selected_batch_size
)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 1, 16)             1408
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 4)                 336
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 1, 4)              0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1, 4)              144
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 1, 16)             1344
# _________________________________________________________________
# time_distributed (TimeDistri (None, 1, 5)              85
# =================================================================
# Total params: 3,317
# Trainable params: 3,317
# Non-trainable params: 0
# _________________________________________________________________
# Starting training; got log keys: []
# Start epoch 1 of training; got log keys: []
# Epoch 1/100
# 11828/11829 [============================>.] - ETA: 0s - loss: 0.0493Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from inf to 0.02421671338379383. Saving model to lstm_autoencoder_models/epoch1/ckpt...
# 11829/11829 [==============================] - 16s 1ms/step - loss: 0.0493 - val_loss: 0.0242
# Start epoch 2 of training; got log keys: []
# Epoch 2/100
# 11820/11829 [============================>.] - ETA: 0s - loss: 0.0241Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.02421671338379383 to 0.022082993760704994. Saving model to lstm_autoencoder_models/epoch2/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0241 - val_loss: 0.0221
# Start epoch 3 of training; got log keys: []
# Epoch 3/100
# 11821/11829 [============================>.] - ETA: 0s - loss: 0.0230Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.022082993760704994
#
# Val_loss improved from 0.022082993760704994 to 0.02211032435297966. Saving model to lstm_autoencoder_models/epoch3/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0229 - val_loss: 0.0221
# Start epoch 4 of training; got log keys: []
# Epoch 4/100
# 11792/11829 [============================>.] - ETA: 0s - loss: 0.0226Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.02211032435297966 to 0.02202053926885128. Saving model to lstm_autoencoder_models/epoch4/ckpt...
# 11829/11829 [==============================] - 18s 2ms/step - loss: 0.0225 - val_loss: 0.0220
# Start epoch 5 of training; got log keys: []
# Epoch 5/100
# 11815/11829 [============================>.] - ETA: 0s - loss: 0.0223Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.02202053926885128 to 0.021334586665034294. Saving model to lstm_autoencoder_models/epoch5/ckpt...
# 11829/11829 [==============================] - 20s 2ms/step - loss: 0.0223 - val_loss: 0.0213
# Start epoch 6 of training; got log keys: []
# Epoch 6/100
# 11816/11829 [============================>.] - ETA: 0s - loss: 0.0221Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.021334586665034294 to 0.021065501496195793. Saving model to lstm_autoencoder_models/epoch6/ckpt...
# 11829/11829 [==============================] - 20s 2ms/step - loss: 0.0221 - val_loss: 0.0211
# Start epoch 7 of training; got log keys: []
# Epoch 7/100
# 11798/11829 [============================>.] - ETA: 0s - loss: 0.0220Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.021065501496195793
#
# Val_loss improved from 0.021065501496195793 to 0.021560853347182274. Saving model to lstm_autoencoder_models/epoch7/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0219 - val_loss: 0.0216
# Start epoch 8 of training; got log keys: []
# Epoch 8/100
# 11826/11829 [============================>.] - ETA: 0s - loss: 0.0218Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.021560853347182274 to 0.02060971036553383. Saving model to lstm_autoencoder_models/epoch8/ckpt...
# 11829/11829 [==============================] - 22s 2ms/step - loss: 0.0218 - val_loss: 0.0206
# Start epoch 9 of training; got log keys: []
# Epoch 9/100
# 11815/11829 [============================>.] - ETA: 0s - loss: 0.0217Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.02060971036553383 to 0.02034945972263813. Saving model to lstm_autoencoder_models/epoch9/ckpt...
# 11829/11829 [==============================] - 26s 2ms/step - loss: 0.0217 - val_loss: 0.0203
# Start epoch 10 of training; got log keys: []
# Epoch 10/100
# 11811/11829 [============================>.] - ETA: 0s - loss: 0.0216Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.02034945972263813
#
# Val_loss improved from 0.02034945972263813 to 0.021263886243104935. Saving model to lstm_autoencoder_models/epoch10/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0216 - val_loss: 0.0213
# Start epoch 11 of training; got log keys: []
# Epoch 11/100
# 11807/11829 [============================>.] - ETA: 0s - loss: 0.0216Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.021263886243104935 to 0.020675359293818474. Saving model to lstm_autoencoder_models/epoch11/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0215 - val_loss: 0.0207
# Start epoch 12 of training; got log keys: []
# Epoch 12/100
# 11808/11829 [============================>.] - ETA: 0s - loss: 0.0215Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.020675359293818474 to 0.020428098738193512. Saving model to lstm_autoencoder_models/epoch12/ckpt...
# 11829/11829 [==============================] - 18s 2ms/step - loss: 0.0215 - val_loss: 0.0204
# Start epoch 13 of training; got log keys: []
# Epoch 13/100
# 11823/11829 [============================>.] - ETA: 0s - loss: 0.0214Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.020428098738193512
#
# Val_loss improved from 0.020428098738193512 to 0.020739659667015076. Saving model to lstm_autoencoder_models/epoch13/ckpt...
# 11829/11829 [==============================] - 24s 2ms/step - loss: 0.0214 - val_loss: 0.0207
# Start epoch 14 of training; got log keys: []
# Epoch 14/100
# 11817/11829 [============================>.] - ETA: 0s - loss: 0.0214Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.020739659667015076 to 0.020261360332369804. Saving model to lstm_autoencoder_models/epoch14/ckpt...
# 11829/11829 [==============================] - 22s 2ms/step - loss: 0.0214 - val_loss: 0.0203
# Start epoch 15 of training; got log keys: []
# Epoch 15/100
# 11806/11829 [============================>.] - ETA: 0s - loss: 0.0213Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.020261360332369804 to 0.01969141513109207. Saving model to lstm_autoencoder_models/epoch15/ckpt...
# 11829/11829 [==============================] - 20s 2ms/step - loss: 0.0213 - val_loss: 0.0197
# Start epoch 16 of training; got log keys: []
# Epoch 16/100
# 11814/11829 [============================>.] - ETA: 0s - loss: 0.0211Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.01969141513109207 to 0.01952601969242096. Saving model to lstm_autoencoder_models/epoch16/ckpt...
# 11829/11829 [==============================] - 20s 2ms/step - loss: 0.0211 - val_loss: 0.0195
# Start epoch 17 of training; got log keys: []
# Epoch 17/100
# 11820/11829 [============================>.] - ETA: 0s - loss: 0.0202Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.01952601969242096 to 0.019481578841805458. Saving model to lstm_autoencoder_models/epoch17/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0202 - val_loss: 0.0195
# Start epoch 18 of training; got log keys: []
# Epoch 18/100
# 11806/11829 [============================>.] - ETA: 0s - loss: 0.0197Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.019481578841805458
#
# Val_loss improved from 0.019481578841805458 to 0.019737521186470985. Saving model to lstm_autoencoder_models/epoch18/ckpt...
# 11829/11829 [==============================] - 24s 2ms/step - loss: 0.0197 - val_loss: 0.0197
# Start epoch 19 of training; got log keys: []
# Epoch 19/100
# 11824/11829 [============================>.] - ETA: 0s - loss: 0.0195Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.019737521186470985 to 0.019115794450044632. Saving model to lstm_autoencoder_models/epoch19/ckpt...
# 11829/11829 [==============================] - 23s 2ms/step - loss: 0.0194 - val_loss: 0.0191
# Start epoch 20 of training; got log keys: []
# Epoch 20/100
# 11820/11829 [============================>.] - ETA: 0s - loss: 0.0193Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.019115794450044632 to 0.017812732607126236. Saving model to lstm_autoencoder_models/epoch20/ckpt...
# 11829/11829 [==============================] - 25s 2ms/step - loss: 0.0193 - val_loss: 0.0178
# Start epoch 21 of training; got log keys: []
# Epoch 21/100
# 11822/11829 [============================>.] - ETA: 0s - loss: 0.0191Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.017812732607126236
#
# Val_loss improved from 0.017812732607126236 to 0.018614426255226135. Saving model to lstm_autoencoder_models/epoch21/ckpt...
# 11829/11829 [==============================] - 25s 2ms/step - loss: 0.0191 - val_loss: 0.0186
# Start epoch 22 of training; got log keys: []
# Epoch 22/100
# 11829/11829 [==============================] - ETA: 0s - loss: 0.0191Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.018614426255226135 to 0.01791161671280861. Saving model to lstm_autoencoder_models/epoch22/ckpt...
# 11829/11829 [==============================] - 22s 2ms/step - loss: 0.0191 - val_loss: 0.0179
# Start epoch 23 of training; got log keys: []
# Epoch 23/100
# 11826/11829 [============================>.] - ETA: 0s - loss: 0.0190Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.01791161671280861
#
# Val_loss improved from 0.01791161671280861 to 0.01848003827035427. Saving model to lstm_autoencoder_models/epoch23/ckpt...
# 11829/11829 [==============================] - 25s 2ms/step - loss: 0.0190 - val_loss: 0.0185
# Start epoch 24 of training; got log keys: []
# Epoch 24/100
# 11817/11829 [============================>.] - ETA: 0s - loss: 0.0189Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.01848003827035427 to 0.017717035487294197. Saving model to lstm_autoencoder_models/epoch24/ckpt...
# 11829/11829 [==============================] - 23s 2ms/step - loss: 0.0189 - val_loss: 0.0177
# Start epoch 25 of training; got log keys: []
# Epoch 25/100
# 11809/11829 [============================>.] - ETA: 0s - loss: 0.0188Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.017717035487294197
#
# Val_loss improved from 0.017717035487294197 to 0.018744952976703644. Saving model to lstm_autoencoder_models/epoch25/ckpt...
# 11829/11829 [==============================] - 26s 2ms/step - loss: 0.0188 - val_loss: 0.0187
# Start epoch 26 of training; got log keys: []
# Epoch 26/100
# 11824/11829 [============================>.] - ETA: 0s - loss: 0.0188Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.018744952976703644 to 0.01823248714208603. Saving model to lstm_autoencoder_models/epoch26/ckpt...
# 11829/11829 [==============================] - 21s 2ms/step - loss: 0.0188 - val_loss: 0.0182
# Start epoch 27 of training; got log keys: []
# Epoch 27/100
# 11820/11829 [============================>.] - ETA: 0s - loss: 0.0187Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.01823248714208603 to 0.017900099977850914. Saving model to lstm_autoencoder_models/epoch27/ckpt...
# 11829/11829 [==============================] - 25s 2ms/step - loss: 0.0187 - val_loss: 0.0179
# Start epoch 28 of training; got log keys: []
# Epoch 28/100
# 11813/11829 [============================>.] - ETA: 0s - loss: 0.0187Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.017900099977850914
#
# Val_loss improved from 0.017900099977850914 to 0.01814698800444603. Saving model to lstm_autoencoder_models/epoch28/ckpt...
# 11829/11829 [==============================] - 21s 2ms/step - loss: 0.0187 - val_loss: 0.0181
# Start epoch 29 of training; got log keys: []
# Epoch 29/100
# 11806/11829 [============================>.] - ETA: 0s - loss: 0.0187Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.01814698800444603 to 0.017594940960407257. Saving model to lstm_autoencoder_models/epoch29/ckpt...
# 11829/11829 [==============================] - 26s 2ms/step - loss: 0.0187 - val_loss: 0.0176
# Start epoch 30 of training; got log keys: []
# Epoch 30/100
# 11812/11829 [============================>.] - ETA: 0s - loss: 0.0186Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.017594940960407257 to 0.017346585169434547. Saving model to lstm_autoencoder_models/epoch30/ckpt...
# 11829/11829 [==============================] - 25s 2ms/step - loss: 0.0186 - val_loss: 0.0173
# Start epoch 31 of training; got log keys: []
# Epoch 31/100
# 11824/11829 [============================>.] - ETA: 0s - loss: 0.0186Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.017346585169434547
#
# Val_loss improved from 0.017346585169434547 to 0.017511915415525436. Saving model to lstm_autoencoder_models/epoch31/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0186 - val_loss: 0.0175
# Start epoch 32 of training; got log keys: []
# Epoch 32/100
# 11799/11829 [============================>.] - ETA: 0s - loss: 0.0186Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.017511915415525436
#
# Val_loss improved from 0.017511915415525436 to 0.019037645310163498. Saving model to lstm_autoencoder_models/epoch32/ckpt...
# 11829/11829 [==============================] - 20s 2ms/step - loss: 0.0186 - val_loss: 0.0190
# Start epoch 33 of training; got log keys: []
# Epoch 33/100
# 11807/11829 [============================>.] - ETA: 0s - loss: 0.0186Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.019037645310163498 to 0.01732838898897171. Saving model to lstm_autoencoder_models/epoch33/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0186 - val_loss: 0.0173
# Start epoch 34 of training; got log keys: []
# Epoch 34/100
# 11810/11829 [============================>.] - ETA: 0s - loss: 0.0185Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.01732838898897171
#
# Val_loss improved from 0.01732838898897171 to 0.017366938292980194. Saving model to lstm_autoencoder_models/epoch34/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0185 - val_loss: 0.0174
# Start epoch 35 of training; got log keys: []
# Epoch 35/100
# 11806/11829 [============================>.] - ETA: 0s - loss: 0.0185Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.017366938292980194
#
# Val_loss improved from 0.017366938292980194 to 0.017969714477658272. Saving model to lstm_autoencoder_models/epoch35/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0185 - val_loss: 0.0180
# Start epoch 36 of training; got log keys: []
# Epoch 36/100
# 11822/11829 [============================>.] - ETA: 0s - loss: 0.0184Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.017969714477658272 to 0.017544521018862724. Saving model to lstm_autoencoder_models/epoch36/ckpt...
# 11829/11829 [==============================] - 20s 2ms/step - loss: 0.0184 - val_loss: 0.0175
# Start epoch 37 of training; got log keys: []
# Epoch 37/100
# 11815/11829 [============================>.] - ETA: 0s - loss: 0.0184Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.017544521018862724 to 0.016994567587971687. Saving model to lstm_autoencoder_models/epoch37/ckpt...
# 11829/11829 [==============================] - 23s 2ms/step - loss: 0.0184 - val_loss: 0.0170
# Start epoch 38 of training; got log keys: []
# Epoch 38/100
# 11820/11829 [============================>.] - ETA: 0s - loss: 0.0184Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.016994567587971687 to 0.016888383775949478. Saving model to lstm_autoencoder_models/epoch38/ckpt...
# 11829/11829 [==============================] - 23s 2ms/step - loss: 0.0184 - val_loss: 0.0169
# Start epoch 39 of training; got log keys: []
# Epoch 39/100
# 11802/11829 [============================>.] - ETA: 0s - loss: 0.0184Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.016888383775949478 to 0.01681835763156414. Saving model to lstm_autoencoder_models/epoch39/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0183 - val_loss: 0.0168
# Start epoch 40 of training; got log keys: []
# Epoch 40/100
# 11810/11829 [============================>.] - ETA: 0s - loss: 0.0183Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.01681835763156414
#
# Val_loss improved from 0.01681835763156414 to 0.0170427355915308. Saving model to lstm_autoencoder_models/epoch40/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0183 - val_loss: 0.0170
# Start epoch 41 of training; got log keys: []
# Epoch 41/100
# 11803/11829 [============================>.] - ETA: 0s - loss: 0.0183Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.0170427355915308
#
# Val_loss improved from 0.0170427355915308 to 0.017071200534701347. Saving model to lstm_autoencoder_models/epoch41/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0183 - val_loss: 0.0171
# Start epoch 42 of training; got log keys: []
# Epoch 42/100
# 11815/11829 [============================>.] - ETA: 0s - loss: 0.0183Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.017071200534701347
#
# Val_loss improved from 0.017071200534701347 to 0.017888473346829414. Saving model to lstm_autoencoder_models/epoch42/ckpt...
# 11829/11829 [==============================] - 18s 2ms/step - loss: 0.0183 - val_loss: 0.0179
# Start epoch 43 of training; got log keys: []
# Epoch 43/100
# 11814/11829 [============================>.] - ETA: 0s - loss: 0.0183Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.017888473346829414 to 0.01693646050989628. Saving model to lstm_autoencoder_models/epoch43/ckpt...
# 11829/11829 [==============================] - 18s 2ms/step - loss: 0.0183 - val_loss: 0.0169
# Start epoch 44 of training; got log keys: []
# Epoch 44/100
# 11801/11829 [============================>.] - ETA: 0s - loss: 0.0182Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.01693646050989628
#
# Val_loss improved from 0.01693646050989628 to 0.01731625571846962. Saving model to lstm_autoencoder_models/epoch44/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0182 - val_loss: 0.0173
# Start epoch 45 of training; got log keys: []
# Epoch 45/100
# 11812/11829 [============================>.] - ETA: 0s - loss: 0.0182Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.01731625571846962 to 0.01690022647380829. Saving model to lstm_autoencoder_models/epoch45/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0182 - val_loss: 0.0169
# Start epoch 46 of training; got log keys: []
# Epoch 46/100
# 11798/11829 [============================>.] - ETA: 0s - loss: 0.0182Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.01690022647380829 to 0.016762780025601387. Saving model to lstm_autoencoder_models/epoch46/ckpt...
# 11829/11829 [==============================] - 18s 2ms/step - loss: 0.0182 - val_loss: 0.0168
# Start epoch 47 of training; got log keys: []
# Epoch 47/100
# 11817/11829 [============================>.] - ETA: 0s - loss: 0.0182Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.016762780025601387
#
# Val_loss improved from 0.016762780025601387 to 0.017068488523364067. Saving model to lstm_autoencoder_models/epoch47/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0182 - val_loss: 0.0171
# Start epoch 48 of training; got log keys: []
# Epoch 48/100
# 11827/11829 [============================>.] - ETA: 0s - loss: 0.0181Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.017068488523364067 to 0.016707269474864006. Saving model to lstm_autoencoder_models/epoch48/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0181 - val_loss: 0.0167
# Start epoch 49 of training; got log keys: []
# Epoch 49/100
# 11808/11829 [============================>.] - ETA: 0s - loss: 0.0181Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.016707269474864006
#
# Val_loss improved from 0.016707269474864006 to 0.017999764531850815. Saving model to lstm_autoencoder_models/epoch49/ckpt...
# 11829/11829 [==============================] - 18s 2ms/step - loss: 0.0181 - val_loss: 0.0180
# Start epoch 50 of training; got log keys: []
# Epoch 50/100
# 11829/11829 [==============================] - ETA: 0s - loss: 0.0181Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.017999764531850815 to 0.01727534644305706. Saving model to lstm_autoencoder_models/epoch50/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0181 - val_loss: 0.0173
# Start epoch 51 of training; got log keys: []
# Epoch 51/100
# 11805/11829 [============================>.] - ETA: 0s - loss: 0.0181Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.01727534644305706 to 0.01663380302488804. Saving model to lstm_autoencoder_models/epoch51/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0181 - val_loss: 0.0166
# Start epoch 52 of training; got log keys: []
# Epoch 52/100
# 11821/11829 [============================>.] - ETA: 0s - loss: 0.0181Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.01663380302488804
#
# Val_loss improved from 0.01663380302488804 to 0.016700366511940956. Saving model to lstm_autoencoder_models/epoch52/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0181 - val_loss: 0.0167
# Start epoch 53 of training; got log keys: []
# Epoch 53/100
# 11828/11829 [============================>.] - ETA: 0s - loss: 0.0181Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.016700366511940956
#
# Val_loss improved from 0.016700366511940956 to 0.01683039963245392. Saving model to lstm_autoencoder_models/epoch53/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0181 - val_loss: 0.0168
# Start epoch 54 of training; got log keys: []
# Epoch 54/100
# 11806/11829 [============================>.] - ETA: 0s - loss: 0.0180Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.01683039963245392 to 0.016651000827550888. Saving model to lstm_autoencoder_models/epoch54/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0180 - val_loss: 0.0167
# Start epoch 55 of training; got log keys: []
# Epoch 55/100
# 11825/11829 [============================>.] - ETA: 0s - loss: 0.0180Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.016651000827550888 to 0.016631711274385452. Saving model to lstm_autoencoder_models/epoch55/ckpt...
# 11829/11829 [==============================] - 25s 2ms/step - loss: 0.0180 - val_loss: 0.0166
# Start epoch 56 of training; got log keys: []
# Epoch 56/100
# 11826/11829 [============================>.] - ETA: 0s - loss: 0.0180Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.016631711274385452 to 0.016589757055044174. Saving model to lstm_autoencoder_models/epoch56/ckpt...
# 11829/11829 [==============================] - 21s 2ms/step - loss: 0.0180 - val_loss: 0.0166
# Start epoch 57 of training; got log keys: []
# Epoch 57/100
# 11809/11829 [============================>.] - ETA: 0s - loss: 0.0180Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.016589757055044174
#
# Val_loss improved from 0.016589757055044174 to 0.017587164416909218. Saving model to lstm_autoencoder_models/epoch57/ckpt...
# 11829/11829 [==============================] - 27s 2ms/step - loss: 0.0180 - val_loss: 0.0176
# Start epoch 58 of training; got log keys: []
# Epoch 58/100
# 11818/11829 [============================>.] - ETA: 0s - loss: 0.0180Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.017587164416909218 to 0.01724269799888134. Saving model to lstm_autoencoder_models/epoch58/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0180 - val_loss: 0.0172
# Start epoch 59 of training; got log keys: []
# Epoch 59/100
# 11822/11829 [============================>.] - ETA: 0s - loss: 0.0180Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.01724269799888134 to 0.016623767092823982. Saving model to lstm_autoencoder_models/epoch59/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0180 - val_loss: 0.0166
# Start epoch 60 of training; got log keys: []
# Epoch 60/100
# 11810/11829 [============================>.] - ETA: 0s - loss: 0.0180Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.016623767092823982 to 0.016575925052165985. Saving model to lstm_autoencoder_models/epoch60/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0179 - val_loss: 0.0166
# Start epoch 61 of training; got log keys: []
# Epoch 61/100
# 11807/11829 [============================>.] - ETA: 0s - loss: 0.0180Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.016575925052165985 to 0.01655130833387375. Saving model to lstm_autoencoder_models/epoch61/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0180 - val_loss: 0.0166
# Start epoch 62 of training; got log keys: []
# Epoch 62/100
# 11819/11829 [============================>.] - ETA: 0s - loss: 0.0180Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.01655130833387375
#
# Val_loss improved from 0.01655130833387375 to 0.017422642558813095. Saving model to lstm_autoencoder_models/epoch62/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0180 - val_loss: 0.0174
# Start epoch 63 of training; got log keys: []
# Epoch 63/100
# 11811/11829 [============================>.] - ETA: 0s - loss: 0.0180Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.017422642558813095 to 0.01710696332156658. Saving model to lstm_autoencoder_models/epoch63/ckpt...
# 11829/11829 [==============================] - 21s 2ms/step - loss: 0.0179 - val_loss: 0.0171
# Start epoch 64 of training; got log keys: []
# Epoch 64/100
# 11814/11829 [============================>.] - ETA: 0s - loss: 0.0179Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.01710696332156658 to 0.016519803553819656. Saving model to lstm_autoencoder_models/epoch64/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0179 - val_loss: 0.0165
# Start epoch 65 of training; got log keys: []
# Epoch 65/100
# 11805/11829 [============================>.] - ETA: 0s - loss: 0.0180Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.016519803553819656
#
# Val_loss improved from 0.016519803553819656 to 0.017281226813793182. Saving model to lstm_autoencoder_models/epoch65/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0179 - val_loss: 0.0173
# Start epoch 66 of training; got log keys: []
# Epoch 66/100
# 11828/11829 [============================>.] - ETA: 0s - loss: 0.0179Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.017281226813793182 to 0.016663815826177597. Saving model to lstm_autoencoder_models/epoch66/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0179 - val_loss: 0.0167
# Start epoch 67 of training; got log keys: []
# Epoch 67/100
# 11800/11829 [============================>.] - ETA: 0s - loss: 0.0179Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.016663815826177597 to 0.01645437814295292. Saving model to lstm_autoencoder_models/epoch67/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0179 - val_loss: 0.0165
# Start epoch 68 of training; got log keys: []
# Epoch 68/100
# 11824/11829 [============================>.] - ETA: 0s - loss: 0.0179Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.01645437814295292
#
# Val_loss improved from 0.01645437814295292 to 0.0170237235724926. Saving model to lstm_autoencoder_models/epoch68/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0179 - val_loss: 0.0170
# Start epoch 69 of training; got log keys: []
# Epoch 69/100
# 11797/11829 [============================>.] - ETA: 0s - loss: 0.0179Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.0170237235724926 to 0.01673063449561596. Saving model to lstm_autoencoder_models/epoch69/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0179 - val_loss: 0.0167
# Start epoch 70 of training; got log keys: []
# Epoch 70/100
# 11803/11829 [============================>.] - ETA: 0s - loss: 0.0179Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.01673063449561596
#
# Val_loss improved from 0.01673063449561596 to 0.017014453187584877. Saving model to lstm_autoencoder_models/epoch70/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0179 - val_loss: 0.0170
# Start epoch 71 of training; got log keys: []
# Epoch 71/100
# 11803/11829 [============================>.] - ETA: 0s - loss: 0.0179Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.017014453187584877 to 0.01634257659316063. Saving model to lstm_autoencoder_models/epoch71/ckpt...
# 11829/11829 [==============================] - 19s 2ms/step - loss: 0.0179 - val_loss: 0.0163
# Start epoch 72 of training; got log keys: []
# Epoch 72/100
# 11818/11829 [============================>.] - ETA: 0s - loss: 0.0178Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.01634257659316063
#
# Val_loss improved from 0.01634257659316063 to 0.017760466784238815. Saving model to lstm_autoencoder_models/epoch72/ckpt...
# 11829/11829 [==============================] - 25s 2ms/step - loss: 0.0178 - val_loss: 0.0178
# Start epoch 73 of training; got log keys: []
# Epoch 73/100
# 11824/11829 [============================>.] - ETA: 0s - loss: 0.0178Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.017760466784238815 to 0.017020009458065033. Saving model to lstm_autoencoder_models/epoch73/ckpt...
# 11829/11829 [==============================] - 24s 2ms/step - loss: 0.0178 - val_loss: 0.0170
# Start epoch 74 of training; got log keys: []
# Epoch 74/100
# 11819/11829 [============================>.] - ETA: 0s - loss: 0.0179Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.017020009458065033
#
# Val_loss improved from 0.017020009458065033 to 0.017456064000725746. Saving model to lstm_autoencoder_models/epoch74/ckpt...
# 11829/11829 [==============================] - 24s 2ms/step - loss: 0.0179 - val_loss: 0.0175
# Start epoch 75 of training; got log keys: []
# Epoch 75/100
# 11812/11829 [============================>.] - ETA: 0s - loss: 0.0179Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.017456064000725746 to 0.01633012294769287. Saving model to lstm_autoencoder_models/epoch75/ckpt...
# 11829/11829 [==============================] - 26s 2ms/step - loss: 0.0179 - val_loss: 0.0163
# Start epoch 76 of training; got log keys: []
# Epoch 76/100
# 11826/11829 [============================>.] - ETA: 0s - loss: 0.0178Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.01633012294769287
#
# Val_loss improved from 0.01633012294769287 to 0.017236266285181046. Saving model to lstm_autoencoder_models/epoch76/ckpt...
# 11829/11829 [==============================] - 28s 2ms/step - loss: 0.0178 - val_loss: 0.0172
# Start epoch 77 of training; got log keys: []
# Epoch 77/100
# 11808/11829 [============================>.] - ETA: 0s - loss: 0.0179Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.017236266285181046 to 0.016524748876690865. Saving model to lstm_autoencoder_models/epoch77/ckpt...
# 11829/11829 [==============================] - 22s 2ms/step - loss: 0.0178 - val_loss: 0.0165
# Start epoch 78 of training; got log keys: []
# Epoch 78/100
# 11815/11829 [============================>.] - ETA: 0s - loss: 0.0178Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.016524748876690865
#
# Val_loss improved from 0.016524748876690865 to 0.016610639169812202. Saving model to lstm_autoencoder_models/epoch78/ckpt...
# 11829/11829 [==============================] - 26s 2ms/step - loss: 0.0178 - val_loss: 0.0166
# Start epoch 79 of training; got log keys: []
# Epoch 79/100
# 11800/11829 [============================>.] - ETA: 0s - loss: 0.0179Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.016610639169812202
#
# Val_loss improved from 0.016610639169812202 to 0.016977529972791672. Saving model to lstm_autoencoder_models/epoch79/ckpt...
# 11829/11829 [==============================] - 29s 2ms/step - loss: 0.0178 - val_loss: 0.0170
# Start epoch 80 of training; got log keys: []
# Epoch 80/100
# 11819/11829 [============================>.] - ETA: 0s - loss: 0.0178Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.016977529972791672 to 0.016668355092406273. Saving model to lstm_autoencoder_models/epoch80/ckpt...
# 11829/11829 [==============================] - 26s 2ms/step - loss: 0.0178 - val_loss: 0.0167
# Start epoch 81 of training; got log keys: []
# Epoch 81/100
# 11821/11829 [============================>.] - ETA: 0s - loss: 0.0179Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.016668355092406273 to 0.01654655672609806. Saving model to lstm_autoencoder_models/epoch81/ckpt...
# 11829/11829 [==============================] - 22s 2ms/step - loss: 0.0178 - val_loss: 0.0165
# Start epoch 82 of training; got log keys: []
# Epoch 82/100
# 11823/11829 [============================>.] - ETA: 0s - loss: 0.0178Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.01654655672609806
#
# Val_loss improved from 0.01654655672609806 to 0.016577215865254402. Saving model to lstm_autoencoder_models/epoch82/ckpt...
# 11829/11829 [==============================] - 24s 2ms/step - loss: 0.0178 - val_loss: 0.0166
# Start epoch 83 of training; got log keys: []
# Epoch 83/100
# 11821/11829 [============================>.] - ETA: 0s - loss: 0.0178Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.016577215865254402 to 0.016444455832242966. Saving model to lstm_autoencoder_models/epoch83/ckpt...
# 11829/11829 [==============================] - 21s 2ms/step - loss: 0.0178 - val_loss: 0.0164
# Start epoch 84 of training; got log keys: []
# Epoch 84/100
# 11824/11829 [============================>.] - ETA: 0s - loss: 0.0178Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.016444455832242966
#
# Val_loss improved from 0.016444455832242966 to 0.017008185386657715. Saving model to lstm_autoencoder_models/epoch84/ckpt...
# 11829/11829 [==============================] - 29s 2ms/step - loss: 0.0178 - val_loss: 0.0170
# Start epoch 85 of training; got log keys: []
# Epoch 85/100
# 11805/11829 [============================>.] - ETA: 0s - loss: 0.0178Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.017008185386657715 to 0.016670383512973785. Saving model to lstm_autoencoder_models/epoch85/ckpt...
# 11829/11829 [==============================] - 27s 2ms/step - loss: 0.0178 - val_loss: 0.0167
# Start epoch 86 of training; got log keys: []
# Epoch 86/100
# 11815/11829 [============================>.] - ETA: 0s - loss: 0.0178Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.016670383512973785
#
# Val_loss improved from 0.016670383512973785 to 0.01704159751534462. Saving model to lstm_autoencoder_models/epoch86/ckpt...
# 11829/11829 [==============================] - 24s 2ms/step - loss: 0.0178 - val_loss: 0.0170
# Start epoch 87 of training; got log keys: []
# Epoch 87/100
# 11798/11829 [============================>.] - ETA: 0s - loss: 0.0178Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.01704159751534462 to 0.01633460633456707. Saving model to lstm_autoencoder_models/epoch87/ckpt...
# 11829/11829 [==============================] - 26s 2ms/step - loss: 0.0178 - val_loss: 0.0163
# Start epoch 88 of training; got log keys: []
# Epoch 88/100
# 11824/11829 [============================>.] - ETA: 0s - loss: 0.0178Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.01633460633456707
#
# Val_loss improved from 0.01633460633456707 to 0.01676095649600029. Saving model to lstm_autoencoder_models/epoch88/ckpt...
# 11829/11829 [==============================] - 23s 2ms/step - loss: 0.0178 - val_loss: 0.0168
# Start epoch 89 of training; got log keys: []
# Epoch 89/100
# 11823/11829 [============================>.] - ETA: 0s - loss: 0.0178Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.01676095649600029
#
# Val_loss improved from 0.01676095649600029 to 0.01677265390753746. Saving model to lstm_autoencoder_models/epoch89/ckpt...
# 11829/11829 [==============================] - 27s 2ms/step - loss: 0.0178 - val_loss: 0.0168
# Start epoch 90 of training; got log keys: []
# Epoch 90/100
# 11800/11829 [============================>.] - ETA: 0s - loss: 0.0178Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.01677265390753746
#
# Val_loss improved from 0.01677265390753746 to 0.016860900446772575. Saving model to lstm_autoencoder_models/epoch90/ckpt...
# 11829/11829 [==============================] - 22s 2ms/step - loss: 0.0178 - val_loss: 0.0169
# Start epoch 91 of training; got log keys: []
# Epoch 91/100
# 11807/11829 [============================>.] - ETA: 0s - loss: 0.0178Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.016860900446772575 to 0.01667620800435543. Saving model to lstm_autoencoder_models/epoch91/ckpt...
# 11829/11829 [==============================] - 25s 2ms/step - loss: 0.0178 - val_loss: 0.0167
# Start epoch 92 of training; got log keys: []
# Epoch 92/100
# 11823/11829 [============================>.] - ETA: 0s - loss: 0.0178Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.01667620800435543 to 0.016661861911416054. Saving model to lstm_autoencoder_models/epoch92/ckpt...
# 11829/11829 [==============================] - 23s 2ms/step - loss: 0.0178 - val_loss: 0.0167
# Start epoch 93 of training; got log keys: []
# Epoch 93/100
# 11814/11829 [============================>.] - ETA: 0s - loss: 0.0178Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.016661861911416054
#
# Val_loss improved from 0.016661861911416054 to 0.01683807000517845. Saving model to lstm_autoencoder_models/epoch93/ckpt...
# 11829/11829 [==============================] - 26s 2ms/step - loss: 0.0178 - val_loss: 0.0168
# Start epoch 94 of training; got log keys: []
# Epoch 94/100
# 11826/11829 [============================>.] - ETA: 0s - loss: 0.0178Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.01683807000517845 to 0.016545960679650307. Saving model to lstm_autoencoder_models/epoch94/ckpt...
# 11829/11829 [==============================] - 27s 2ms/step - loss: 0.0178 - val_loss: 0.0165
# Start epoch 95 of training; got log keys: []
# Epoch 95/100
# 11799/11829 [============================>.] - ETA: 0s - loss: 0.0178Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.016545960679650307 to 0.016485299915075302. Saving model to lstm_autoencoder_models/epoch95/ckpt...
# 11829/11829 [==============================] - 28s 2ms/step - loss: 0.0178 - val_loss: 0.0165
# Start epoch 96 of training; got log keys: []
# Epoch 96/100
# 11808/11829 [============================>.] - ETA: 0s - loss: 0.0178Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.016485299915075302 to 0.01647641509771347. Saving model to lstm_autoencoder_models/epoch96/ckpt...
# 11829/11829 [==============================] - 22s 2ms/step - loss: 0.0178 - val_loss: 0.0165
# Start epoch 97 of training; got log keys: []
# Epoch 97/100
# 11813/11829 [============================>.] - ETA: 0s - loss: 0.0178Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.01647641509771347
#
# Val_loss improved from 0.01647641509771347 to 0.016712285578250885. Saving model to lstm_autoencoder_models/epoch97/ckpt...
# 11829/11829 [==============================] - 28s 2ms/step - loss: 0.0177 - val_loss: 0.0167
# Start epoch 98 of training; got log keys: []
# Epoch 98/100
# 11829/11829 [==============================] - ETA: 0s - loss: 0.0177Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss improved from 0.016712285578250885 to 0.01637931726872921. Saving model to lstm_autoencoder_models/epoch98/ckpt...
# 11829/11829 [==============================] - 26s 2ms/step - loss: 0.0177 - val_loss: 0.0164
# Start epoch 99 of training; got log keys: []
# Epoch 99/100
# 11821/11829 [============================>.] - ETA: 0s - loss: 0.0178Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.01637931726872921
#
# Val_loss improved from 0.01637931726872921 to 0.016686936840415. Saving model to lstm_autoencoder_models/epoch99/ckpt...
# 11829/11829 [==============================] - 23s 2ms/step - loss: 0.0178 - val_loss: 0.0167
# Start epoch 100 of training; got log keys: []
# Epoch 100/100
# 11822/11829 [============================>.] - ETA: 0s - loss: 0.0178Start testing; got log keys: []
# Stop testing; got log keys: ['loss']
#
# Val_loss did not improve from 0.016686936840415
#
# Val_loss improved from 0.016686936840415 to 0.016705887392163277. Saving model to lstm_autoencoder_models/epoch100/ckpt...
# 11829/11829 [==============================] - 29s 2ms/step - loss: 0.0178 - val_loss: 0.0167
# Stop training; got log keys: ['loss', 'val_loss']

# %% [markdown]
# Plot loss

# %%
metric = "loss"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %% [markdown]
# Choosing a treshold

# %%
x_train_pred = predict_results(lstm_autoencoder, x_train_healthy)
x_train_pred_ = x_train_pred.reshape(x_train_pred.shape[0], x_train_pred.shape[2])
x_train_healthy_ = x_train_healthy.reshape(x_train_healthy.shape[0], x_train_healthy.shape[2])
train_mae_loss = np.mean(np.abs(x_train_pred_ - x_train_healthy_), axis=1)
scored_d = {}

plt.figure()
plt.figure(figsize=(16,9), dpi=80)
plt.title('Loss Distribution Train', fontsize=16)
plt.grid()
sns.distplot(train_mae_loss,
             bins = 20, 
             kde= True,
            color = 'blue');
# plt.xlim([0.0,.5])
# Out:
# /home/fmurdaca/.local/share/virtualenvs/manuela-dev-SY9YZsQk/lib/python3.6/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Using the **threshold**, we can turn the problem into a simple binary classification task:
#
# If the reconstruction loss for an example is below the threshold, we’ll classify it as healthy.
# Alternatively, if the loss is higher than the threshold, we’ll classify it as an anomaly.

# %%
results_summary = []
from numpy import arange, mean

for threshold_ in arange(min(train_mae_loss), max(train_mae_loss), mean(train_mae_loss)):
    x_test_pred = predict_results(lstm_autoencoder, x_test_healthy)

    x_test_pred_ = x_test_pred.reshape(x_test_pred.shape[0], x_test_pred.shape[2])
    x_test_healthy_ = x_test_healthy.reshape(x_test_healthy.shape[0], x_test_healthy.shape[2])

    test_mae_loss = np.mean(np.abs(x_test_pred_ - x_test_healthy_), axis=1)

    scored_test = {}
    scored_test['Loss_mae'] = test_mae_loss
    scored_test['Threshold'] = threshold_
    scored_t = pd.DataFrame(scored_test)
    scored_t['Healthy_pred'] = scored_t['Loss_mae'] < scored_t['Threshold']
    scored_t['Healthy_pred_int'] = scored_t['Healthy_pred'].astype(int)

    scored_t['Target'] = y_test_healthy.values
    no_anomalies = scored_t[scored_t['Healthy_pred_int'] == 0]
    percentage_identified = no_anomalies.shape[0]/scored_t.shape[0]
    
    start = time()
    x_all_pred = predict_results(lstm_autoencoder, x_all_anomalies)
    end = time()

    x_all_pred_ = x_all_pred.reshape(x_all_pred.shape[0], x_all_pred.shape[2])
    x_all_anomalies_ = x_all_anomalies.reshape(x_all_anomalies.shape[0], x_all_anomalies.shape[2])

    all_mae_loss = np.mean(np.abs(x_all_pred_ - x_all_anomalies_), axis=1)

    scored_test = {}
    scored_test['Loss_mae'] = all_mae_loss
    scored_test['Threshold'] = threshold_
    scored_a = pd.DataFrame(scored_test)
    scored_a['Anomaly_pred'] = scored_a['Loss_mae'] > scored_a['Threshold']
    scored_a['Anomaly_pred_int'] = scored_a['Anomaly_pred'].astype(int)

    scored_a['Target'] = y_all_anomalies.values

    with_anomalies = scored_a[scored_a['Anomaly_pred_int'] == 1]
    percentage_identified_val_set = with_anomalies.shape[0]/scored_a.shape[0]

    f1_score_ = f1_score(scored_a['Target'], scored_a['Anomaly_pred_int'])

    result_summary = {
        "threshold": threshold_,
        "percentage_anomalies_test": percentage_identified*100,
        "percentage_anomalies_val": percentage_identified_val_set*100,
        "f1_score": f1_score_
    }
    
    results_summary.append(result_summary)

pd.DataFrame(results_summary)
# Out:
#    threshold  percentage_anomalies_test  percentage_anomalies_val  f1_score
# 0   0.001420                 100.000000                100.000000  1.000000
# 1   0.018913                   8.644222                100.000000  1.000000
# 2   0.036406                   7.825296                100.000000  1.000000
# 3   0.053899                   7.825296                100.000000  1.000000
# 4   0.071392                   7.643312                100.000000  1.000000
# 5   0.088886                   6.778890                100.000000  1.000000
# 6   0.106379                   4.458599                100.000000  1.000000
# 7   0.123872                   2.820746                100.000000  1.000000
# 8   0.141365                   0.591447                 99.761905  0.998808

# %%
threshold = 0.136306

# %%
x_test_pred = predict_results(lstm_autoencoder, x_test_healthy)

x_test_pred_ = x_test_pred.reshape(x_test_pred.shape[0], x_test_pred.shape[2])
x_test_healthy_ = x_test_healthy.reshape(x_test_healthy.shape[0], x_test_healthy.shape[2])

test_mae_loss = np.mean(np.abs(x_test_pred_ - x_test_healthy_), axis=1)

scored_test = {}
scored_test['Loss_mae'] = test_mae_loss
scored_test['Threshold'] = threshold
scored_t = pd.DataFrame(scored_test)
scored_t['Healthy_pred'] = scored_t['Loss_mae'] < scored_t['Threshold']
scored_t['Healthy_pred_int'] = scored_t['Healthy_pred'].astype(int)

scored_t['Target'] = y_test_healthy.values
scored_t.describe()

plt.figure()
plt.figure(figsize=(16,9), dpi=80)
plt.title('Loss Distribution Test', fontsize=16)
plt.grid()
sns.distplot(test_mae_loss,
             bins = 20, 
             kde= True,
            color = 'blue');
# plt.xlim([0.0,.5])
# Out:
# /home/fmurdaca/.local/share/virtualenvs/manuela-dev-SY9YZsQk/lib/python3.6/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
no_anomalies = scored_t[scored_t['Healthy_pred_int'] == 0]
percentage_identified = no_anomalies.shape[0]/scored_t.shape[0]
print(f"Percentage of anomalies in healthy data identified: {percentage_identified*100:.2f}%")
# Out:
# Percentage of anomalies in healthy data identified: 1.09%

# %% [markdown]
# ## Predict anomalies

# %%
start = time()
x_all_pred = predict_results(lstm_autoencoder, x_all_anomalies)
end = time()

# Print and return results
print ("Made predictions in {:.4f} seconds.".format(end - start))

x_all_pred_ = x_all_pred.reshape(x_all_pred.shape[0], x_all_pred.shape[2])
x_all_anomalies_ = x_all_anomalies.reshape(x_all_anomalies.shape[0], x_all_anomalies.shape[2])

all_mae_loss = np.mean(np.abs(x_all_pred_ - x_all_anomalies_), axis=1)

scored_test = {}
scored_test['Loss_mae'] = all_mae_loss
scored_test['Threshold'] = threshold
scored_a = pd.DataFrame(scored_test)
scored_a['Anomaly_pred'] = scored_a['Loss_mae'] > scored_a['Threshold']
scored_a['Anomaly_pred_int'] = scored_a['Anomaly_pred'].astype(int)

scored_a['Target'] = y_all_anomalies.values
scored_a.head()
# Out:
# Made predictions in 0.0602 seconds.
#    Loss_mae  Threshold  Anomaly_pred  Anomaly_pred_int  Target
# 0  0.484086   0.136306          True                 1       1
# 1  0.455965   0.136306          True                 1       1
# 2  0.397048   0.136306          True                 1       1
# 3  0.705545   0.136306          True                 1       1
# 4  0.577181   0.136306          True                 1       1

# %%
scored_a.describe()
# Out:
#          Loss_mae   Threshold  Anomaly_pred_int  Target
# count  420.000000  420.000000        420.000000   420.0
# mean     2.234482    0.136306          0.997619     1.0
# std      1.047440    0.000000          0.048795     0.0
# min      0.136188    0.136306          0.000000     1.0
# 25%      1.768499    0.136306          1.000000     1.0
# 50%      2.384155    0.136306          1.000000     1.0
# 75%      3.152145    0.136306          1.000000     1.0
# max      3.906270    0.136306          1.000000     1.0

# %%
plt.figure()
plt.figure(figsize=(16,9), dpi=80)
plt.title('Loss Distribution Anomalies', fontsize=16)
plt.grid()
sns.distplot(all_mae_loss,
             bins = 20, 
             kde= True,
            color = 'blue');
# Out:
# /home/fmurdaca/.local/share/virtualenvs/manuela-dev-SY9YZsQk/lib/python3.6/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
with_anomalies = scored_a[scored_a['Anomaly_pred_int'] == 1]
percentage_identified = with_anomalies.shape[0]/scored_a.shape[0]
printmd(f"Percentage of anomalies identified in anomalies set: **{percentage_identified*100:.2f}%**")

print(classification_report(scored_a['Target'], scored_a['Anomaly_pred_int']))

f1_score_ = f1_score(scored_a['Target'], scored_a['Anomaly_pred_int'])
printmd("F1 score for anomalies set: **{:.4f}**.".format(f1_score_))

# Deep Learning models (Supervised Learning)

summary_results.append(
    {
        "Model": "LSTM Autoencoder",
        "Model type": "Deep Learning model",
        "F1 score": f1_score_
    }
)
# Out:
# Percentage of anomalies identified in anomalies set: **99.76%**
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      1.00      1.00       420
#
#     accuracy                           1.00       420
#    macro avg       0.50      0.50      0.50       420
# weighted avg       1.00      1.00      1.00       420
# /home/fmurdaca/.local/share/virtualenvs/manuela-dev-SY9YZsQk/lib64/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# F1 score for anomalies set: **0.9988**.

# %%
results = pd.DataFrame(summary_results)
results.sort_values(by=['F1 score'], ascending=False)
# Out:
#                     Model           Model type  F1 score
# 0  DecisionTreeClassifier    Statistical model  1.000000
# 1                     SVC    Statistical model  1.000000
# 3        LSTM Autoencoder  Deep Learning model  0.998808
# 2              GaussianNB    Statistical model  0.992857

# %% [markdown]
# **Brief interpretation:**
#
# From the results in the above table we can see that using Deep Learning Model for Anomaly Detection gives the best results in terms of predictions.
#
# Important to notice that for the model selected no Hyperparameter Tuning was performed.
#
# Let's save and load the model just to double check that it works.

# %%
# from joblib import dump, load

# tf.keras.models.save_model(
#     lstm_autoencoder, "file_name", overwrite=True, include_optimizer=True, save_format=None,
#     signatures=None, options=None
# )

# %%
# Validate that the model can be loaded

# load the model from disk
# loaded_model = tf.keras.models.load_model(file_name)

from pathlib import Path

current_path = Path.cwd()
print(current_path)
# Create a new model instance
loaded_model = get_model(X=x_train_healthy)
# Restore the weights
epoch_selected = "epoch100"
checkpoint_selected = "epoch100ckpt"
path_to_weights = current_path.joinpath("lstm_autoencoder_models", epoch_selected, checkpoint_selected)
print(path_to_weights)
loaded_model.load_weights(current_path.joinpath("lstm_autoencoder_models", epoch_selected, checkpoint_selected))
# Out:
# /home/fmurdaca/work/manuela-dev/ml-models/anomaly-detection
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 1, 16)             1408
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 4)                 336
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 1, 4)              0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 1, 4)              144
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 1, 16)             1344
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 1, 5)              85
# =================================================================
# Total params: 3,317
# Trainable params: 3,317
# Non-trainable params: 0
# _________________________________________________________________
# /home/fmurdaca/work/manuela-dev/ml-models/anomaly-detection/lstm_autoencoder_models/epoch100/epoch100ckpt

# %%
results_summary = []
from numpy import arange

for threshold_ in arange(min(train_mae_loss), max(train_mae_loss), mean(train_mae_loss)):
    x_test_pred = predict_results(loaded_model, x_test_healthy)

    x_test_pred_ = x_test_pred.reshape(x_test_pred.shape[0], x_test_pred.shape[2])
    x_test_healthy_ = x_test_healthy.reshape(x_test_healthy.shape[0], x_test_healthy.shape[2])

    test_mae_loss = np.mean(np.abs(x_test_pred_ - x_test_healthy_), axis=1)

    scored_test = {}
    scored_test['Loss_mae'] = test_mae_loss
    scored_test['Threshold'] = threshold_
    scored_tt = pd.DataFrame(scored_test)
    scored_tt['Healthy_pred'] = scored_tt['Loss_mae'] < scored_tt['Threshold']
    scored_tt['Healthy_pred_int'] = scored_tt['Healthy_pred'].astype(int)

    scored_tt['Target'] = y_test_healthy.values
    no_anomalies = scored_tt[scored_tt['Healthy_pred_int'] == 0]
    percentage_identified = no_anomalies.shape[0]/scored_t.shape[0]

    
    x_all_pred = predict_results(loaded_model, x_all_anomalies)
    all_mae_loss = np.mean(np.abs(x_all_pred - x_all_anomalies), axis=1)

    scored_test_aa = {}
    scored_test_aa['Loss_mae'] = all_mae_loss[:, 0]
    scored_test_aa['Threshold'] = threshold_

    scored_aa = pd.DataFrame(scored_test_aa)
    scored_aa['Anomaly_pred'] = scored_aa['Loss_mae'] > scored_aa['Threshold']
    scored_aa['Anomaly_pred_int'] = scored_aa['Anomaly_pred'].astype(int)

    scored_aa['Target'] = y_all_anomalies.values

    with_anomalies = scored_aa[scored_aa['Anomaly_pred_int'] == 1]
    percentage_identified_val_set = with_anomalies.shape[0]/scored_aa.shape[0]

    f1_score_ = f1_score(scored_aa['Target'], scored_aa['Anomaly_pred_int'])

    result_summary = {
        "threshold": threshold_,
        "percentage_anomalies_test": percentage_identified*100,
        "percentage_anomalies_val": percentage_identified_val_set*100,
        "f1_score": f1_score_
    }
    
    results_summary.append(result_summary)

pd.DataFrame(results_summary)
# Out:
#    threshold  percentage_anomalies_test  percentage_anomalies_val  f1_score
# 0   0.001420                  98.680619                100.000000  1.000000
# 1   0.018913                   4.868062                100.000000  1.000000
# 2   0.036406                   2.957234                100.000000  1.000000
# 3   0.053899                   2.957234                100.000000  1.000000
# 4   0.071392                   2.820746                100.000000  1.000000
# 5   0.088886                   2.365787                100.000000  1.000000
# 6   0.106379                   1.728844                 99.761905  0.998808
# 7   0.123872                   1.228389                 99.761905  0.998808
# 8   0.141365                   0.227480                 99.761905  0.998808

# %%
x_all_pred = predict_results(loaded_model, x_all_anomalies)
all_mae_loss = np.mean(np.abs(x_all_pred - x_all_anomalies), axis=1)

scored_test = {}
scored_test['Loss_mae'] = all_mae_loss[:, 0]
scored_test['Threshold'] = threshold

scored_a = pd.DataFrame(scored_test)
scored_a['Anomaly_pred'] = scored_a['Loss_mae'] > scored_a['Threshold']
scored_a['Anomaly_pred_int'] = scored_a['Anomaly_pred'].astype(int)

scored_a['Target'] = y_all_anomalies.values

with_anomalies = scored_a[scored_a['Anomaly_pred_int'] == 1]
percentage_identified = with_anomalies.shape[0]/scored_a.shape[0]
print(f"Percentage of anomalies identified: {percentage_identified*100:.2f}%")

print(classification_report(scored_a['Target'], scored_a['Anomaly_pred_int']))

f1_score_ = f1_score(scored_a['Target'], scored_a['Anomaly_pred_int'])
print("Score is: {:.4f}.".format(f1_score_))
# Out:
# Percentage of anomalies identified: 99.76%
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      1.00      1.00       420
#
#     accuracy                           1.00       420
#    macro avg       0.50      0.50      0.50       420
# weighted avg       1.00      1.00      1.00       420
#
# Score is: 0.9988.
# /home/fmurdaca/.local/share/virtualenvs/manuela-dev-SY9YZsQk/lib64/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Prototype class for Seldon model serving
# For serving the model using Seldon, we need to implement a simple call with an constructor and predict method. Let's try it out here:

# %%
import os, sys

class AnomalyDetection(object):
    def __init__(self):
        print("Initializing...")
        self.model_file = os.environ.get('MODEL_FILE', 'model.joblib')

        print("Load modelfile: %s" % (self.model_file))
        self.clf = load(open(self.model_file, 'rb'))

    def predict(self, X, feature_names):
        print("Predict features: ", X) 

        prediction = self.clf.predict(X)
        print("Prediction: " , prediction)
        
        return prediction

# %%
p = AnomalyDetection()
    
X = np.asarray([[16.1,  15.40,  15.32,  13.47,  17.70]], dtype=np.float32)
print("Features types: ", type(X),  type(X[0][0]))
print("Predict features: ", X)

prediction = p.clf.predict(X)
print("Prediction: " , prediction)
